# %%
import os,subprocess; os.path.exists("Uploads") or subprocess.run(["git","clone","--quiet","https://github.com/BenKenobi2502/Uploads.git"],stdout=subprocess.DEVNULL,stderr=subprocess.DEVNULL)
# %run "Uploads/Start Up/Start_Up.py"
# Out:
# <style>
#     body, .jp-Notebook, .container, .output_wrapper, .output_area {
#         background: #F5F5DC !important;
#         min-height: 100vh;
#         margin: 0;
#         padding: 0;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         overflow-x: hidden; /* prevent horizontal scrollbars when wide elements are present */
#     }
#
#     .widget-box {
#         background: transparent !important;
#     }
#
#     .centered-vbox {
#         display: flex !important;
#         flex-direction: column !important;
#         align-items: center !important;
#         justify-content: flex-start !important;
#         min-height: 100vh !important;
#         gap: 20px;
#         padding: 30px 20px;
#     }
#
#     .homogenized-button {
#         background: #E74C3C !important;
#         color: white !important;
#         font-weight: bold !important;
#         border-radius: 12px !important;
#         border: none !important;
# ...
